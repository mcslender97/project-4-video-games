# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read cleaned data
df = pd.read_csv('video_games_clean.csv')

# %%
df
# Out:
#                                    Name Platform  Year_of_Release      Genre  \
# 0                            Wii Sports      Wii           2006.0     Sports
# 1                        Mario Kart Wii      Wii           2008.0     Racing
# 2                     Wii Sports Resort      Wii           2009.0     Sports
# 3                 New Super Mario Bros.       DS           2006.0   Platform
# 4                              Wii Play      Wii           2006.0       Misc
# ...                                 ...      ...              ...        ...
# 6888     Mortal Kombat: Deadly Alliance      GBA           2002.0   Fighting
# 6889  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 6890                             Breach       PC           2011.0    Shooter
# 6891            STORM: Frontline Nation       PC           2011.0   Strategy
# 6892                            15 Days       PC           2009.0  Adventure
#
#                          Publisher  Global_Sales  Critic_Score  User_Score  \
# 0                         Nintendo         82.53          76.0         8.0
# 1                         Nintendo         35.52          82.0         8.3
# 2                         Nintendo         32.77          80.0         8.0
# 3                         Nintendo         29.80          89.0         8.5
# 4                         Nintendo         28.92          58.0         6.6
# ...                            ...           ...           ...         ...
# 6888                  Midway Games          0.01          81.0         8.8
# 6889  Konami Digital Entertainment          0.01          80.0         7.6
# 6890                     Destineer          0.01          61.0         5.8
# 6891                       Unknown          0.01          60.0         7.2
# 6892             DTP Entertainment          0.01          63.0         5.8
#
#       User_Count
# 0          322.0
# 1          709.0
# 2          192.0
# 3          431.0
# 4          129.0
# ...          ...
# 6888         9.0
# 6889       412.0
# 6890        43.0
# 6891        13.0
# 6892         8.0
#
# [6893 rows x 9 columns]

# %%
# Shape the data
df.shape
# Out:
# (6893, 9)

# %%
# Show first five records
df.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 1         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 4               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    Global_Sales  Critic_Score  User_Score  User_Count
# 0         82.53          76.0         8.0       322.0
# 1         35.52          82.0         8.3       709.0
# 2         32.77          80.0         8.0       192.0
# 3         29.80          89.0         8.5       431.0
# 4         28.92          58.0         6.6       129.0

# %%
# Show all columns in the dataframe
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher',
#        'Global_Sales', 'Critic_Score', 'User_Score', 'User_Count'],
#       dtype='object')

# %%
# Show last 5 rows
df.tail()
# Out:
#                                    Name Platform  Year_of_Release      Genre  \
# 6888     Mortal Kombat: Deadly Alliance      GBA           2002.0   Fighting
# 6889  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 6890                             Breach       PC           2011.0    Shooter
# 6891            STORM: Frontline Nation       PC           2011.0   Strategy
# 6892                            15 Days       PC           2009.0  Adventure
#
#                          Publisher  Global_Sales  Critic_Score  User_Score  \
# 6888                  Midway Games          0.01          81.0         8.8
# 6889  Konami Digital Entertainment          0.01          80.0         7.6
# 6890                     Destineer          0.01          61.0         5.8
# 6891                       Unknown          0.01          60.0         7.2
# 6892             DTP Entertainment          0.01          63.0         5.8
#
#       User_Count
# 6888         9.0
# 6889       412.0
# 6890        43.0
# 6891        13.0
# 6892         8.0

# %%
#Describe the data
df.describe()
# Out:
#        Year_of_Release  Global_Sales  Critic_Score   User_Score    User_Count
# count      6893.000000   6893.000000   6893.000000  6893.000000   6893.000000
# mean       2007.481793      0.771576     70.261860     7.184985    174.366894
# std           4.236497      1.954908     13.859256     1.439028    584.910760
# min        1985.000000      0.010000     13.000000     0.500000      4.000000
# 25%        2004.000000      0.110000     62.000000     6.500000     11.000000
# 50%        2007.000000      0.290000     72.000000     7.500000     27.000000
# 75%        2011.000000      0.750000     80.000000     8.200000     89.000000
# max        2016.000000     82.530000     98.000000     9.600000  10665.000000

# %%
#Group the sales data of each region in Year_of_Release
df_group=df.groupby('Year_of_Release')['Global_Sales'].sum()
df_group
# Out:
# Year_of_Release
# 1985.0      0.03
# 1988.0      0.03
# 1992.0      0.03
# 1994.0      1.27
# 1996.0     20.35
# 1997.0     36.02
# 1998.0     45.24
# 1999.0     51.17
# 2000.0     81.24
# 2001.0    253.88
# 2002.0    288.84
# 2003.0    255.65
# 2004.0    321.79
# 2005.0    334.32
# 2006.0    416.72
# 2007.0    456.23
# 2008.0    489.96
# 2009.0    460.01
# 2010.0    413.03
# 2011.0    385.07
# 2012.0    293.52
# 2013.0    268.14
# 2014.0    193.14
# 2015.0    160.39
# 2016.0     92.40
# Name: Global_Sales, dtype: float64

# %%
#Plot the sales data of each region in Year_of_Release, showing which region sales was at peak on which year of release
sns.set_style('darkgrid')
sns.set_context('notebook')
sns.barplot(x='Year_of_Release', y='Global_Sales', data=pd.DataFrame(df_group))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27304/4253099148.py in <module>
#       2 sns.set_style('darkgrid')
#       3 sns.set_context('notebook')
# ----> 4 sns.barplot(x='Year_of_Release', y='Global_Sales', data=pd.DataFrame(df_group))
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Year_of_Release'
