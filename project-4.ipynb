# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('video_games.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Shows the first 5 rows of the dataframe
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
#Show if columns have any NaN, N/A or NULL values in boolean format
df.isnull().any()
# Out:
# Name                True
# Platform           False
# Year_of_Release     True
# Genre               True
# Publisher           True
# NA_Sales           False
# EU_Sales           False
# JP_Sales           False
# Other_Sales        False
# Global_Sales       False
# Critic_Score        True
# Critic_Count        True
# User_Score          True
# User_Count          True
# Developer           True
# Rating              True
# dtype: bool

# %%
#Check how many NaN, N/A or NULL values in each column
null_series=df.isnull().sum()
null_series
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
null_df=pd.DataFrame(null_series)

# Show how many null, empty or NaN values in each column with the help of heatmap
sns.heatmap(null_df,annot=True,cmap='coolwarm',fmt='g')
# Out:
# <AxesSubplot:>

# %%
# Drop columns Critic_Count, Developer, JP_Sales, NA_Sales, Other_Sales, Rating, and EU_Sales
df_2=df.drop(['Critic_Count','Developer','JP_Sales','NA_Sales','EU_Sales','Other_Sales','Rating'],axis=1)

df_2
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#Drop the null values containing rows from the df_2
df_3=df_2.dropna()
df_3
# Out:
#                                     Name Platform  Year_of_Release      Genre  \
# 0                             Wii Sports      Wii           2006.0     Sports
# 2                         Mario Kart Wii      Wii           2008.0     Racing
# 3                      Wii Sports Resort      Wii           2009.0     Sports
# 6                  New Super Mario Bros.       DS           2006.0   Platform
# 7                               Wii Play      Wii           2006.0       Misc
# ...                                  ...      ...              ...        ...
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0   Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 16700                             Breach       PC           2011.0    Shooter
# 16706            STORM: Frontline Nation       PC           2011.0   Strategy
# 16709                            15 Days       PC           2009.0  Adventure
#
# ...

# %%
#Export data frame to csv file with no index column
df_3.to_csv('video_games_clean.csv',index=False)
